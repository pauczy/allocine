# %% [markdown]
# # Top 100 movie titles from AlloCiné

# %%
import locale
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import date

locale.setlocale(locale.LC_ALL, 'fr_FR')
# Out:
# 'fr_FR'

# %%
urls = []
for i in range(1, 8):
    if i == 1:
        urls.append("https://www.allocine.fr/films/")
    else:
        urls.append("https://www.allocine.fr/films/?page={}".format(i))

# %%
def get_movie_titles(url): 
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    selection_class='meta-title'
    movie_title_tags=soup.find_all('h2',{'class':selection_class})
    movie_titles=[]
    for tag in movie_title_tags:
        title = tag.find('a').text
        movie_titles.append(title)       
    return movie_titles

# %%
def get_movie_dates(url): 
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    selection_class='meta-body-item meta-body-info'
    movie_year_tags=soup.find_all('div',{'class':selection_class})
    movie_years=[]
    for tag in movie_year_tags:
        year = tag.find('span').text
        movie_years.append(year)       
    return movie_years

# %%
top_movies_titles = []
top_movies_dates = []
for url in urls:
    titles = get_movie_titles(url)
    dates = get_movie_dates(url)
    top_movies_titles.extend(titles)
    top_movies_dates.extend(dates)
movie_data = {'title' : top_movies_titles, 'release date' : top_movies_dates}
pd.set_option("display.max_rows", None)
movies_df = pd.DataFrame(movie_data)
movies_df['release date'] = pd.to_datetime(movies_df['release date'], format='%d %B %Y', errors = 'coerce')

# %%
#uncomment this line to sort movies by release date
#movies_df.sort_values(by=['release date'], inplace=True, ascending = False)

display(movies_df)
# Out:
#                                                  title release date
# 0                                         Bullet Train   2022-08-03
# 1                                                 Nope   2022-08-10
# 2                                 One Piece Film - Red   2022-08-10
# 3                                    Vesper Chronicles   2022-08-17
# 4                              De l'autre côté du ciel   2022-08-17
# 5                        Là où chantent les écrevisses   2022-08-17
# 6                                        La Nuit du 12   2022-07-13
# 7                                    Top Gun: Maverick   2022-05-25
# 8                                    L'Année du requin   2022-08-03
# 9                                            As bestas   2022-07-20
# 10                        Trois Mille ans à t’attendre   2022-08-24
# 11                             Esther 2 : Les Origines   2022-08-17
# 12                          La très très grande classe   2022-08-10
# 13                                    Les Volets verts   2022-08-24
# 14                                                Prey   2022-08-05
# 15                                        Rumba la vie   2022-08-24
# 16                         Krypto et les Super-Animaux   2022-07-27
# 17                              Thor: Love And Thunder   2022-07-13
# 18                                               Beast   2022-08-24
# 19                                   Le Bal de l'Enfer   2022-08-24
# 20               Les Minions 2 : Il était une fois Gru   2022-07-06
# 21                                 Leila et ses frères          NaT
# 22                                               Elvis   2022-06-22
# 23           Les Vieux fourneaux 2 : bons pour l’asile   2022-08-17
# 24                                               Rebel   2022-08-31
# 25                                     La Page blanche   2022-08-31
# 26                   Everything Everywhere All at Once   2022-08-31
# 27                                      La Dégustation   2022-08-31
# 28                                    Les Cinq Diables   2022-08-31
# 29                                             Menteur   2022-07-13
# 30            Tad l'explorateur et la table d'émeraude   2022-08-24
# 31                                  Nos cœurs meurtris   2022-07-29
# 32                                             Sundown   2022-07-27
# 33                                                Dodo   2022-08-10
# 34                           Avec amour et acharnement   2022-08-31
# 35                                         Treize vies   2022-08-05
# 36                                   Decision To Leave   2022-06-29
# 37                   La Dérive des continents (au sud)   2022-08-24
# 38                                  Ducobu Président !   2022-07-13
# 39                    Jurassic World: Le Monde d'après   2022-06-08
# 40                                        The Gray Man   2022-07-22
# 41                                         La Verónica   2022-08-17
# 42                                       Le Samaritain   2022-08-26
# 43                                Les Nuits de Mashhad   2022-07-13
# 44                                     La Petite Bande   2022-07-20
# 45                                       Buzz l'éclair   2022-06-22
# 46                                           Day Shift   2022-08-12
# 47                                  Joyeuse retraite 2   2022-07-20
# 48                               Les Promesses d’Hasan   2022-08-03
# 49                                              Walter   2019-03-20
# 50                                             Tempura   2022-07-20
# 51                                          Stillwater   2021-09-22
# 52                                         Black Phone   2022-06-22
# 53                                       Pourris gâtés   2021-09-15
# 54                                            En corps   2022-03-30
# 55                                         En décalage   2022-08-03
# 56                                            Wild Men   2022-08-24
# 57           Qu'est-ce qu'on a tous fait au Bon Dieu ?   2022-04-06
# 58                                            La Momie   2017-06-14
# 59                   Les Derniers jours dans le désert   2022-08-17
# 60                                         The Sadness   2022-07-06
# 61                                     Les Traducteurs   2020-01-29
# 62                         365 Jours : L'Année d'Après   2022-08-19
# 63                                              Selfie   2020-01-15
# 64                                             Pupille   2018-12-05
# 65                              Amants super-héroïques   2022-08-03
# 66                                              Carter   2022-08-05
# 67                                          Two Lovers   2008-11-19
# 68                                      America Latina   2022-08-17
# 69                                        Irréductible   2022-06-29
# 70                                            Memories   1997-04-15
# 71                                  Laal Singh Chaddha   2022-08-11
# 72                                        La Traversée   2022-06-29
# 73                                   Rifkin's Festival   2022-07-13
# 74                                Costa Brava, Lebanon   2022-07-27
# 75                               Des Feux dans la nuit   2022-08-03
# 76                                               Gerry   2003-11-11
# 77                   Mia et moi, L’Héroïne de Centopia   2022-07-20
# 78                                           Les SEGPA   2022-04-20
# 79                                  Une Vie ou l'Autre   2022-08-17
# 80                                          The Batman   2022-03-02
# 81                                             Top Gun   1986-09-17
# 82                          Qiu Ju, une femme chinoise   1992-12-09
# 83                                            Rashômon   1952-04-18
# 84                                                Luck   2022-08-05
# 85   Les Animaux Fantastiques : les Secrets de Dumb...   2022-04-13
# 86                                       The Innocents   2022-02-09
# 87                               Un homme à la hauteur   2016-05-04
# 88                                              Memory   2022-07-29
# 89                                             365 Dni   2020-06-26
# 90                                 Mi iubita mon amour   2022-07-27
# 91                                     Last Seen Alive   2022-08-01
# 92                                         Incantation   2022-07-08
# 93                    Vol au-dessus d'un nid de coucou   1976-03-01
# 94                                        Les Méchants   2021-09-08
# 95         Doctor Strange in the Multiverse of Madness   2022-05-04
# 96                                    Un jour sans fin   1993-07-28
# 97                                           Le Dindon   2019-09-25
# 98                                       Swimming Pool   2003-05-21
# 99            Encanto, la fantastique famille Madrigal   2021-11-24
# 100                                             Esther   2009-12-30
# 101                             La Chair de l'orchidée   1975-02-01
# 102                                     Peter von Kant   2022-07-06
# 103                               Le Rapport Auschwitz   2022-07-27
# 104                                             Avatar   2009-12-16

# %%
today = date.today().strftime("%d_%m_%Y")
movies_df.to_csv("top_movies_allocine_{}.tsv".format(today), sep = '\t', index = False)
